# %% [markdown]
# ![image.png](attachment:image.png)
# \
# \
# checkpointer help you to implement short term memory in langraph

# %% [markdown]
# checkpointer + thread id ===> STM

# %% [markdown]
# ![image.png](attachment:image.png)
# \
# \
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### without STM

# %% [markdown]
# ### with STM

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# \
# \
# to fight these we have these methods called triming

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
